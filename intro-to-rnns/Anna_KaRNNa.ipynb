# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, we'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use. Here I'm creating a couple dictionaries to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
with open('anna.txt', 'r') as f:
    text=f.read()
vocab = sorted(set(text))
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
encoded = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see the characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([31, 64, 57, 72, 76, 61, 74,  1, 16,  0,  0,  0, 36, 57, 72, 72, 81,
#         1, 62, 57, 69, 65, 68, 65, 61, 75,  1, 57, 74, 61,  1, 57, 68, 68,
#         1, 57, 68, 65, 67, 61, 26,  1, 61, 78, 61, 74, 81,  1, 77, 70, 64,
#        57, 72, 72, 81,  1, 62, 57, 69, 65, 68, 81,  1, 65, 75,  1, 77, 70,
#        64, 57, 72, 72, 81,  1, 65, 70,  1, 65, 76, 75,  1, 71, 79, 70,  0,
#        79, 57, 81, 13,  0,  0, 33, 78, 61, 74, 81, 76, 64, 65, 70], dtype=int32)

# %% [markdown]
# Since the network is working with individual characters, it's similar to a classification problem in which we are trying to predict the next character from the previous text.  Here's how many 'classes' our network has to pick from.

# %%
len(vocab)
# Out:
# 83

# %% [markdown]
# ## Making training mini-batches
#
# Here is where we'll make our mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
#
# We start with our text encoded as integers in one long array in `encoded`. Let's create a function that will give us an iterator for our batches. I like using [generator functions](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/) to do this. Then we can pass `encoded` into this function and get our batch generator.
#
# The first thing we need to do is discard some of the text so we only have completely full batches. Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps. Then, to get the total number of batches, $K$, we can make from the array `arr`, you divide the length of `arr` by the number of characters per batch. Once you know the number of batches, you can get the total number of characters to keep from `arr`, $N * M * K$.
#
# After that, we need to split `arr` into $N$ sequences. You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences (`batch_size` below), let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$.
#
# Now that we have this array, we can iterate through it to get our batches. The idea is each batch is a $N \times M$ window on the $N \times (M * K)$ array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character.
#
# The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.
#
# > **Exercise:** Write the code for creating batches in the function below. The exercises in this notebook _will not be easy_. I've provided a notebook with solutions alongside this notebook. If you get stuck, checkout the solutions. The most important thing is that you don't copy and paste the code into here, **type out the solution code yourself.**

# %%
def get_batches(arr, batch_size, n_steps):
    '''Create a generator that returns batches of size
       batch_size x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       batch_size: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
    # Get the number of characters per batch and number of batches we can make
    characters_per_batch = batch_size * n_steps
    n_batches = len(arr) // characters_per_batch
    
    # Keep only enough characters to make full batches
    arr = arr[:characters_per_batch*n_batches]
    
    # Reshape into batch_size rows
    arr = arr.reshape((batch_size, -1))
    
    for n in range(0, arr.shape[1], n_steps):
        # The features
        x = arr[:, n:n+n_steps]
        # The targets, shifted by one
        y_temp = arr[:, n+1:n+n_steps+1]
        
        # For the very last batch, y will be one character short at the end of 
        # the sequences which breaks things. To get around this, I'll make an 
        # array of the appropriate size first, of all zeros, then add the targets.
        # This will introduce a small artifact in the last batch, but it won't matter.
        y = np.zeros(x.shape, dtype=x.dtype)
        y[:,:y_temp.shape[1]] = y_temp
        
        yield x, y

# %% [markdown]
# Now I'll make my data sets and we can check out what's going on here. Here I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
# Out:
# x
#  [[31 64 57 72 76 61 74  1 16  0]
#  [ 1 57 69  1 70 71 76  1 63 71]
#  [78 65 70 13  0  0  3 53 61 75]
#  [70  1 60 77 74 65 70 63  1 64]
#  [ 1 65 76  1 65 75 11  1 75 65]
#  [ 1 37 76  1 79 57 75  0 71 70]
#  [64 61 70  1 59 71 69 61  1 62]
#  [26  1 58 77 76  1 70 71 79  1]
#  [76  1 65 75 70  7 76 13  1 48]
#  [ 1 75 57 65 60  1 76 71  1 64]]
#
# y
#  [[64 57 72 76 61 74  1 16  0  0]
#  [57 69  1 70 71 76  1 63 71 65]
#  [65 70 13  0  0  3 53 61 75 11]
#  [ 1 60 77 74 65 70 63  1 64 65]
#  [65 76  1 65 75 11  1 75 65 74]
#  [37 76  1 79 57 75  0 71 70 68]
#  [61 70  1 59 71 69 61  1 62 71]
#  [ 1 58 77 76  1 70 71 79  1 75]
#  [ 1 65 75 70  7 76 13  1 48 64]
#  [75 57 65 60  1 76 71  1 64 61]]

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ## Building the model
#
# Below is where you'll build the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
#
# ### Inputs
#
# First off we'll create our input placeholders. As usual we need placeholders for the training data and the targets. We'll also create a placeholder for dropout layers called `keep_prob`. This will be a scalar, that is a 0-D tensor. To make a scalar, you create a placeholder without giving it a size.
#
# > **Exercise:** Create the input placeholders in the function below.

# %%
def build_inputs(batch_size, num_steps):
    ''' Define placeholders for inputs, targets, and dropout 
    
        Arguments
        ---------
        batch_size: Batch size, number of sequences per batch
        num_steps: Number of sequence steps in a batch
        
    '''
    # Declare placeholders we'll feed into the graph
    inputs = tf.placeholder(tf.int32, (batch_size, num_steps), name='inputs')
    targets = tf.placeholder(tf.int32, (batch_size, num_steps), name='targets')
    
    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    return inputs, targets, keep_prob

# %% [markdown]
# ### LSTM Cell
#
# Here we will create the LSTM cell we'll use in the hidden layer. We'll use this cell as a building block for the RNN. So we aren't actually defining the RNN here, just the type of cell we'll use in the hidden layer.
#
# We first create a basic LSTM cell with
#
# ```python
# lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
# ```
#
# where `num_units` is the number of units in the hidden layers in the cell. Then we can add dropout by wrapping it with
#
# ```python
# tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
# ```
# You pass in a cell and it will automatically add dropout to the inputs or outputs. Finally, we can stack up the LSTM cells into layers with [`tf.contrib.rnn.MultiRNNCell`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/rnn/MultiRNNCell). With this, you pass in a list of cells and it will send the output of one cell into the next cell. Previously with TensorFlow 1.0, you could do this
#
# ```python
# tf.contrib.rnn.MultiRNNCell([cell]*num_layers)
# ```
#
# This might look a little weird if you know Python well because this will create a list of the same `cell` object. However, TensorFlow 1.0 will create different weight matrices for all `cell` objects. But, starting with TensorFlow 1.1 you actually need to create new cell objects in the list. To get it to work in TensorFlow 1.1, it should look like
#
# ```python
# def build_cell(num_units, keep_prob):
#     lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
#     drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
#
#     return drop
#
# tf.contrib.rnn.MultiRNNCell([build_cell(num_units, keep_prob) for _ in range(num_layers)])
# ```
#
# Even though this is actually multiple LSTM cells stacked on each other, you can treat the multiple layers as one cell.
#
# We also need to create an initial cell state of all zeros. This can be done like so
#
# ```python
# initial_state = cell.zero_state(batch_size, tf.float32)
# ```
#
# Below, we implement the `build_lstm` function to create these LSTM cells and the initial state.

# %%
def build_cell(num_units, keep_prob):
    lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)

    return drop

# %%
def build_lstm(lstm_size, num_layers, batch_size, keep_prob):
    ''' Build LSTM cell.
    
        Arguments
        ---------
        keep_prob: Scalar tensor (tf.placeholder) for the dropout keep probability
        lstm_size: Size of the hidden layers in the LSTM cells
        num_layers: Number of LSTM layers
        batch_size: Batch size

    '''
    
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([build_cell(lstm_size, keep_prob) for _ in range(num_layers)])
    initial_state = cell.zero_state(batch_size, tf.float32)
    
    return cell, initial_state

# %% [markdown]
# ### RNN Output
#
# Here we'll create the output layer. We need to connect the output of the RNN cells to a full connected layer with a softmax output. The softmax output gives us a probability distribution we can use to predict the next character, so we want this layer to have size $C$, the number of classes/characters we have in our text.
#
# If our input has batch size $N$, number of steps $M$, and the hidden layer has $L$ hidden units, then the output is a 3D tensor with size $N \times M \times L$. The output of each LSTM cell has size $L$, we have $M$ of them, one for each sequence step, and we have $N$ sequences. So the total size is $N \times M \times L$.
#
# We are using the same fully connected layer, the same weights, for each of the outputs. Then, to make things easier, we should reshape the outputs into a 2D tensor with shape $(M * N) \times L$. That is, one row for each sequence and step, where the values of each row are the output from the LSTM cells. We get the LSTM output as a list, `lstm_output`. First we need to concatenate this whole list into one array with [`tf.concat`](https://www.tensorflow.org/api_docs/python/tf/concat). Then, reshape it (with `tf.reshape`) to size $(M * N) \times L$.
#
# One we have the outputs reshaped, we can do the matrix multiplication with the weights. We need to wrap the weight and bias variables in a variable scope with `tf.variable_scope(scope_name)` because there are weights being created in the LSTM cells. TensorFlow will throw an error if the weights created here have the same names as the weights created in the LSTM cells, which they will be default. To avoid this, we wrap the variables in a variable scope so we can give them unique names.
#
# > **Exercise:** Implement the output layer in the function below.

# %%
def build_output(lstm_output, in_size, out_size):
    ''' Build a softmax layer, return the softmax output and logits.
    
        Arguments
        ---------
        
        lstm_output: List of output tensors from the LSTM layer
        in_size: Size of the input tensor, for example, size of the LSTM cells
        out_size: Size of this softmax layer
    
    '''

    # Reshape output so it's a bunch of rows, one row for each step for each sequence.
    # Concatenate lstm_output over axis 1 (the columns)
    seq_output = tf.concat(lstm_output, axis=1)
    # Reshape seq_output to a 2D tensor with lstm_size columns
    x = tf.reshape(seq_output, [-1, in_size])
    
    # Connect the RNN outputs to a softmax layer
    with tf.variable_scope('softmax'):
        # Create the weight and bias variables here
        softmax_w = tf.Variable(tf.truncated_normal((in_size, out_size), stddev=0.1))
        softmax_b = tf.Variable(tf.zeros(out_size))
    
    # Since output is a bunch of rows of RNN cell outputs, logits will be a bunch
    # of rows of logit outputs, one for each step and sequence
    logits = tf.matmul(x, softmax_w) + softmax_b
    
    # Use softmax to get the probabilities for predicted characters
    out = tf.nn.softmax(logits, name='predictions')
    
    return out, logits

# %% [markdown]
# ### Training loss
#
# Next up is the training loss. We get the logits and targets and calculate the softmax cross-entropy loss. First we need to one-hot encode the targets, we're getting them as encoded characters. Then, reshape the one-hot targets so it's a 2D tensor with size $(M*N) \times C$ where $C$ is the number of classes/characters we have. Remember that we reshaped the LSTM outputs and ran them through a fully connected layer with $C$ units. So our logits will also have size $(M*N) \times C$.
#
# Then we run the logits and targets through `tf.nn.softmax_cross_entropy_with_logits` and find the mean to get the loss.
#
# >**Exercise:** Implement the loss calculation in the function below.

# %%
def build_loss(logits, targets, lstm_size, num_classes):
    ''' Calculate the loss from the logits and the targets.
    
        Arguments
        ---------
        logits: Logits from final fully connected layer
        targets: Targets for supervised learning
        lstm_size: Number of LSTM hidden units
        num_classes: Number of classes in targets
        
    '''
    
    # One-hot encode targets and reshape to match logits, one row per sequence per step
    y_one_hot = tf.one_hot(targets, num_classes)
    y_reshaped =  tf.reshape(y_one_hot, logits.get_shape())
    
    # Softmax cross entropy loss
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_reshaped))
    
    return loss

# %% [markdown]
# ### Optimizer
#
# Here we build the optimizer. Normal RNNs have have issues gradients exploding and disappearing. LSTMs fix the disappearance problem, but the gradients can still grow without bound. To fix this, we can clip the gradients above some threshold. That is, if a gradient is larger than that threshold, we set it to the threshold. This will ensure the gradients never grow overly large. Then we use an AdamOptimizer for the learning step.

# %%
def build_optimizer(loss, learning_rate, grad_clip):
    ''' Build optmizer for training, using gradient clipping.
    
        Arguments:
        loss: Network loss
        learning_rate: Learning rate for optimizer
    
    '''
    
    # Optimizer for training, using gradient clipping to control exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    return optimizer

# %% [markdown]
# ### Build the network
#
# Now we can put all the pieces together and build a class for the network. To actually run data through the LSTM cells, we will use [`tf.nn.dynamic_rnn`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/nn/dynamic_rnn). This function will pass the hidden and cell states across LSTM cells appropriately for us. It returns the outputs for each LSTM cell at each step for each sequence in the mini-batch. It also gives us the final LSTM state. We want to save this state as `final_state` so we can pass it to the first LSTM cell in the the next mini-batch run. For `tf.nn.dynamic_rnn`, we pass in the cell and initial state we get from `build_lstm`, as well as our input sequences. Also, we need to one-hot encode the inputs before going into the RNN.
#
# > **Exercise:** Use the functions you've implemented previously and `tf.nn.dynamic_rnn` to build the network.

# %%
class CharRNN:
    
    def __init__(self, num_classes, batch_size=64, num_steps=50, 
                       lstm_size=128, num_layers=2, learning_rate=0.001, 
                       grad_clip=5, sampling=False):
    
        # When we're using this network for sampling later, we'll be passing in
        # one character at a time, so providing an option for that
        if sampling == True:
            batch_size, num_steps = 1, 1
        else:
            batch_size, num_steps = batch_size, num_steps

        tf.reset_default_graph()
        
        # Build the input placeholder tensors
        self.inputs, self.targets, self.keep_prob = build_inputs(batch_size, num_steps)

        # Build the LSTM cell
        cell, self.initial_state = build_lstm(lstm_size, num_layers, batch_size, keep_prob)

        ### Run the data through the RNN layers
        # First, one-hot encode the input tokens
        x_one_hot = tf.one_hot(self.inputs, num_classes)
        
        # Run each sequence step through the RNN with tf.nn.dynamic_rnn 
        outputs, state = tf.nn.dynamic_rnn(cell, x_one_hot, initial_state=self.initial_state)
        self.final_state = state
        
        # Get softmax predictions and logits
        self.prediction, self.logits = build_output(outputs, lstm_size, num_classes)
        
        # Loss and optimizer (with gradient clipping)
        self.loss =  build_loss(self.logits, self.targets, lstm_size, num_classes)
        self.optimizer = build_optimizer(self.loss, learning_rate, grad_clip)

# %% [markdown]
# ## Hyperparameters
#
# Here are the hyperparameters for the network.
#
# * `batch_size` - Number of sequences running through the network in one pass.
# * `num_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lstm_size` - The number of units in the hidden layers.
# * `num_layers` - Number of hidden LSTM layers to use
# * `learning_rate` - Learning rate for training
# * `keep_prob` - The dropout keep probability when training. If you're network is overfitting, try decreasing this.
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `lstm_size` and `num_layers`. I would advise that you always use `num_layers` of either 2/3. The `lstm_size` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `lstm_size` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %%
batch_size = 10         # Sequences per batch
num_steps = 50          # Number of sequence steps per batch
lstm_size = 128         # Size of hidden layers in LSTMs
num_layers = 2          # Number of LSTM layers
learning_rate = 0.01    # Learning rate
keep_prob = 0.5         # Dropout keep probability

# %% [markdown]
# ## Time for training
#
# This is typical training code, passing inputs and targets into the network, then running the optimizer. Here we also get back the final LSTM state for the mini-batch. Then, we pass that state back into the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I save a checkpoint.
#
# Here I'm saving checkpoints with the format
#
# `i{iteration number}_l{# hidden layer units}.ckpt`
#
# > **Exercise:** Set the hyperparameters above to train the network. Watch the training loss, it should be consistently dropping. Also, I highly advise running this on a GPU.

# %%
epochs = 20
# Print losses every N interations
print_every_n = 50

# Save every N iterations
save_every_n = 200

model = CharRNN(len(vocab), batch_size=batch_size, num_steps=num_steps,
                lstm_size=lstm_size, num_layers=num_layers, 
                learning_rate=learning_rate)

saver = tf.train.Saver(max_to_keep=100)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    counter = 0
    for e in range(epochs):
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for x, y in get_batches(encoded, batch_size, num_steps):
            counter += 1
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: keep_prob,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.loss, 
                                                 model.final_state, 
                                                 model.optimizer], 
                                                 feed_dict=feed)
            if (counter % print_every_n == 0):
                end = time.time()
                print('Epoch: {}/{}... '.format(e+1, epochs),
                      'Training Step: {}... '.format(counter),
                      'Training loss: {:.4f}... '.format(batch_loss),
                      '{:.4f} sec/batch'.format((end-start)))
        
            if (counter % save_every_n == 0):
                saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
    
    saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
# Out:
# Epoch: 1/20...  Training Step: 50...  Training loss: 3.1287...  0.0569 sec/batch
# Epoch: 1/20...  Training Step: 100...  Training loss: 2.8318...  0.0568 sec/batch
# Epoch: 1/20...  Training Step: 150...  Training loss: 2.5038...  0.0558 sec/batch
# Epoch: 1/20...  Training Step: 200...  Training loss: 2.5827...  0.0550 sec/batch
# Epoch: 1/20...  Training Step: 250...  Training loss: 2.4158...  0.0548 sec/batch
# Epoch: 1/20...  Training Step: 300...  Training loss: 2.3040...  0.0536 sec/batch
# Epoch: 1/20...  Training Step: 350...  Training loss: 2.2085...  0.0542 sec/batch
# Epoch: 1/20...  Training Step: 400...  Training loss: 2.2554...  0.0545 sec/batch
# Epoch: 1/20...  Training Step: 450...  Training loss: 2.2594...  0.0536 sec/batch
# Epoch: 1/20...  Training Step: 500...  Training loss: 2.3192...  0.0573 sec/batch
# Epoch: 1/20...  Training Step: 550...  Training loss: 2.0690...  0.0541 sec/batch
# Epoch: 1/20...  Training Step: 600...  Training loss: 1.9652...  0.0551 sec/batch
# Epoch: 1/20...  Training Step: 650...  Training loss: 1.9946...  0.0540 sec/batch
# Epoch: 1/20...  Training Step: 700...  Training loss: 2.0380...  0.0555 sec/batch
# Epoch: 1/20...  Training Step: 750...  Training loss: 2.1003...  0.0538 sec/batch
# Epoch: 1/20...  Training Step: 800...  Training loss: 2.0088...  0.0533 sec/batch
# Epoch: 1/20...  Training Step: 850...  Training loss: 2.1602...  0.0543 sec/batch
# Epoch: 1/20...  Training Step: 900...  Training loss: 1.9939...  0.0557 sec/batch
# Epoch: 1/20...  Training Step: 950...  Training loss: 2.0118...  0.0579 sec/batch
# Epoch: 1/20...  Training Step: 1000...  Training loss: 1.9829...  0.0536 sec/batch
# Epoch: 1/20...  Training Step: 1050...  Training loss: 2.0493...  0.0537 sec/batch
# Epoch: 1/20...  Training Step: 1100...  Training loss: 1.9683...  0.0582 sec/batch
# Epoch: 1/20...  Training Step: 1150...  Training loss: 2.0021...  0.0543 sec/batch
# Epoch: 1/20...  Training Step: 1200...  Training loss: 1.9652...  0.0551 sec/batch
# Epoch: 1/20...  Training Step: 1250...  Training loss: 1.8141...  0.0578 sec/batch
# Epoch: 1/20...  Training Step: 1300...  Training loss: 1.9581...  0.0551 sec/batch
# Epoch: 1/20...  Training Step: 1350...  Training loss: 1.8065...  0.0544 sec/batch
# Epoch: 1/20...  Training Step: 1400...  Training loss: 2.0752...  0.0566 sec/batch
# Epoch: 1/20...  Training Step: 1450...  Training loss: 1.8796...  0.0583 sec/batch
# Epoch: 1/20...  Training Step: 1500...  Training loss: 2.0070...  0.0544 sec/batch
# Epoch: 1/20...  Training Step: 1550...  Training loss: 1.8773...  0.0549 sec/batch
# Epoch: 1/20...  Training Step: 1600...  Training loss: 1.9154...  0.0565 sec/batch
# Epoch: 1/20...  Training Step: 1650...  Training loss: 1.8989...  0.0551 sec/batch
# Epoch: 1/20...  Training Step: 1700...  Training loss: 1.9116...  0.0572 sec/batch
# Epoch: 1/20...  Training Step: 1750...  Training loss: 1.9747...  0.0576 sec/batch
# Epoch: 1/20...  Training Step: 1800...  Training loss: 1.9277...  0.0543 sec/batch
# Epoch: 1/20...  Training Step: 1850...  Training loss: 2.0158...  0.0550 sec/batch
# Epoch: 1/20...  Training Step: 1900...  Training loss: 1.7589...  0.0588 sec/batch
# Epoch: 1/20...  Training Step: 1950...  Training loss: 1.8284...  0.0586 sec/batch
# Epoch: 1/20...  Training Step: 2000...  Training loss: 1.8221...  0.0589 sec/batch
# Epoch: 1/20...  Training Step: 2050...  Training loss: 2.0131...  0.0550 sec/batch
# Epoch: 1/20...  Training Step: 2100...  Training loss: 1.8054...  0.0536 sec/batch
# Epoch: 1/20...  Training Step: 2150...  Training loss: 1.8660...  0.0570 sec/batch
# Epoch: 1/20...  Training Step: 2200...  Training loss: 1.7814...  0.0559 sec/batch
# Epoch: 1/20...  Training Step: 2250...  Training loss: 1.8540...  0.0569 sec/batch
# Epoch: 1/20...  Training Step: 2300...  Training loss: 1.7202...  0.0547 sec/batch
# Epoch: 1/20...  Training Step: 2350...  Training loss: 1.8515...  0.0573 sec/batch
# Epoch: 1/20...  Training Step: 2400...  Training loss: 1.9323...  0.0552 sec/batch
# Epoch: 1/20...  Training Step: 2450...  Training loss: 2.0234...  0.0565 sec/batch
# Epoch: 1/20...  Training Step: 2500...  Training loss: 1.7883...  0.0570 sec/batch
# Epoch: 1/20...  Training Step: 2550...  Training loss: 1.8146...  0.0578 sec/batch
# Epoch: 1/20...  Training Step: 2600...  Training loss: 1.7870...  0.0607 sec/batch
# Epoch: 1/20...  Training Step: 2650...  Training loss: 2.0092...  0.0545 sec/batch
# Epoch: 1/20...  Training Step: 2700...  Training loss: 1.9163...  0.0552 sec/batch
# Epoch: 1/20...  Training Step: 2750...  Training loss: 1.7464...  0.0563 sec/batch
# Epoch: 1/20...  Training Step: 2800...  Training loss: 1.7352...  0.0545 sec/batch
# Epoch: 1/20...  Training Step: 2850...  Training loss: 1.8825...  0.0574 sec/batch
# Epoch: 1/20...  Training Step: 2900...  Training loss: 1.6749...  0.0545 sec/batch
# Epoch: 1/20...  Training Step: 2950...  Training loss: 1.6198...  0.0549 sec/batch
# Epoch: 1/20...  Training Step: 3000...  Training loss: 1.7596...  0.0570 sec/batch
# Epoch: 1/20...  Training Step: 3050...  Training loss: 1.9504...  0.0556 sec/batch
# Epoch: 1/20...  Training Step: 3100...  Training loss: 1.8080...  0.0556 sec/batch
# Epoch: 1/20...  Training Step: 3150...  Training loss: 1.7226...  0.0562 sec/batch
# Epoch: 1/20...  Training Step: 3200...  Training loss: 1.8994...  0.0545 sec/batch
# Epoch: 1/20...  Training Step: 3250...  Training loss: 1.8067...  0.0541 sec/batch
# Epoch: 1/20...  Training Step: 3300...  Training loss: 1.8875...  0.0558 sec/batch
# Epoch: 1/20...  Training Step: 3350...  Training loss: 1.6250...  0.0552 sec/batch
# Epoch: 1/20...  Training Step: 3400...  Training loss: 1.7229...  0.0556 sec/batch
# Epoch: 1/20...  Training Step: 3450...  Training loss: 1.7484...  0.0593 sec/batch
# Epoch: 1/20...  Training Step: 3500...  Training loss: 1.7348...  0.0549 sec/batch
# Epoch: 1/20...  Training Step: 3550...  Training loss: 1.8351...  0.0603 sec/batch
# Epoch: 1/20...  Training Step: 3600...  Training loss: 1.8685...  0.0558 sec/batch
# Epoch: 1/20...  Training Step: 3650...  Training loss: 1.9315...  0.0569 sec/batch
# Epoch: 1/20...  Training Step: 3700...  Training loss: 1.7654...  0.0549 sec/batch
# Epoch: 1/20...  Training Step: 3750...  Training loss: 1.8238...  0.0571 sec/batch
# Epoch: 1/20...  Training Step: 3800...  Training loss: 1.7663...  0.0553 sec/batch
# Epoch: 1/20...  Training Step: 3850...  Training loss: 1.7607...  0.0596 sec/batch
# Epoch: 1/20...  Training Step: 3900...  Training loss: 1.9057...  0.0556 sec/batch
# Epoch: 1/20...  Training Step: 3950...  Training loss: 1.7824...  0.0557 sec/batch
# Epoch: 2/20...  Training Step: 4000...  Training loss: 1.7913...  0.0550 sec/batch
# Epoch: 2/20...  Training Step: 4050...  Training loss: 1.7733...  0.0545 sec/batch
# Epoch: 2/20...  Training Step: 4100...  Training loss: 1.7008...  0.0546 sec/batch
# Epoch: 2/20...  Training Step: 4150...  Training loss: 1.6513...  0.0558 sec/batch
# Epoch: 2/20...  Training Step: 4200...  Training loss: 1.6909...  0.0558 sec/batch
# Epoch: 2/20...  Training Step: 4250...  Training loss: 1.7796...  0.0554 sec/batch
# Epoch: 2/20...  Training Step: 4300...  Training loss: 1.8185...  0.0575 sec/batch
# Epoch: 2/20...  Training Step: 4350...  Training loss: 1.7455...  0.0559 sec/batch
# Epoch: 2/20...  Training Step: 4400...  Training loss: 1.6516...  0.0535 sec/batch
# Epoch: 2/20...  Training Step: 4450...  Training loss: 1.7543...  0.0545 sec/batch
# Epoch: 2/20...  Training Step: 4500...  Training loss: 1.7482...  0.0530 sec/batch
# Epoch: 2/20...  Training Step: 4550...  Training loss: 1.8862...  0.0533 sec/batch
# Epoch: 2/20...  Training Step: 4600...  Training loss: 1.8008...  0.0554 sec/batch
# Epoch: 2/20...  Training Step: 4650...  Training loss: 1.8565...  0.0537 sec/batch
# Epoch: 2/20...  Training Step: 4700...  Training loss: 1.6813...  0.0543 sec/batch
# Epoch: 2/20...  Training Step: 4750...  Training loss: 1.8135...  0.0563 sec/batch
# Epoch: 2/20...  Training Step: 4800...  Training loss: 1.6663...  0.0557 sec/batch
# Epoch: 2/20...  Training Step: 4850...  Training loss: 1.7512...  0.0544 sec/batch
# Epoch: 2/20...  Training Step: 4900...  Training loss: 1.7581...  0.0539 sec/batch
# Epoch: 2/20...  Training Step: 4950...  Training loss: 1.7045...  0.0533 sec/batch
# Epoch: 2/20...  Training Step: 5000...  Training loss: 1.7029...  0.0542 sec/batch
# Epoch: 2/20...  Training Step: 5050...  Training loss: 1.6025...  0.0534 sec/batch
# Epoch: 2/20...  Training Step: 5100...  Training loss: 1.6727...  0.0532 sec/batch
# Epoch: 2/20...  Training Step: 5150...  Training loss: 1.7226...  0.0536 sec/batch
# Epoch: 2/20...  Training Step: 5200...  Training loss: 1.8837...  0.0548 sec/batch
# Epoch: 2/20...  Training Step: 5250...  Training loss: 1.6820...  0.0547 sec/batch
# Epoch: 2/20...  Training Step: 5300...  Training loss: 1.8444...  0.0547 sec/batch
# Epoch: 2/20...  Training Step: 5350...  Training loss: 1.7085...  0.0554 sec/batch
# Epoch: 2/20...  Training Step: 5400...  Training loss: 1.8717...  0.0591 sec/batch
# Epoch: 2/20...  Training Step: 5450...  Training loss: 1.7818...  0.0557 sec/batch
# Epoch: 2/20...  Training Step: 5500...  Training loss: 1.8413...  0.0577 sec/batch
# Epoch: 2/20...  Training Step: 5550...  Training loss: 1.6716...  0.0567 sec/batch
# Epoch: 2/20...  Training Step: 5600...  Training loss: 1.8100...  0.0609 sec/batch
# Epoch: 2/20...  Training Step: 5650...  Training loss: 1.6623...  0.0549 sec/batch
# Epoch: 2/20...  Training Step: 5700...  Training loss: 1.6806...  0.0589 sec/batch
# Epoch: 2/20...  Training Step: 5750...  Training loss: 1.7205...  0.0564 sec/batch
# Epoch: 2/20...  Training Step: 5800...  Training loss: 1.6734...  0.0552 sec/batch
# Epoch: 2/20...  Training Step: 5850...  Training loss: 1.8241...  0.0574 sec/batch
# Epoch: 2/20...  Training Step: 5900...  Training loss: 1.7396...  0.0544 sec/batch
# Epoch: 2/20...  Training Step: 5950...  Training loss: 1.7133...  0.0557 sec/batch
# Epoch: 2/20...  Training Step: 6000...  Training loss: 1.6571...  0.0550 sec/batch
# Epoch: 2/20...  Training Step: 6050...  Training loss: 1.6941...  0.0565 sec/batch
# Epoch: 2/20...  Training Step: 6100...  Training loss: 1.8236...  0.0549 sec/batch
# Epoch: 2/20...  Training Step: 6150...  Training loss: 1.7675...  0.0570 sec/batch
# Epoch: 2/20...  Training Step: 6200...  Training loss: 1.7054...  0.0552 sec/batch
# Epoch: 2/20...  Training Step: 6250...  Training loss: 1.6950...  0.0539 sec/batch
# Epoch: 2/20...  Training Step: 6300...  Training loss: 1.6457...  0.0554 sec/batch
# Epoch: 2/20...  Training Step: 6350...  Training loss: 1.8054...  0.0559 sec/batch
# Epoch: 2/20...  Training Step: 6400...  Training loss: 1.6727...  0.0550 sec/batch
# Epoch: 2/20...  Training Step: 6450...  Training loss: 1.8020...  0.0545 sec/batch
# Epoch: 2/20...  Training Step: 6500...  Training loss: 1.7203...  0.0565 sec/batch
# Epoch: 2/20...  Training Step: 6550...  Training loss: 1.7844...  0.0604 sec/batch
# Epoch: 2/20...  Training Step: 6600...  Training loss: 1.8512...  0.0550 sec/batch
# Epoch: 2/20...  Training Step: 6650...  Training loss: 1.5882...  0.0545 sec/batch
# Epoch: 2/20...  Training Step: 6700...  Training loss: 1.6584...  0.0574 sec/batch
# Epoch: 2/20...  Training Step: 6750...  Training loss: 1.6322...  0.0576 sec/batch
# Epoch: 2/20...  Training Step: 6800...  Training loss: 1.7234...  0.0577 sec/batch
# Epoch: 2/20...  Training Step: 6850...  Training loss: 1.6715...  0.0553 sec/batch
# Epoch: 2/20...  Training Step: 6900...  Training loss: 1.6505...  0.0607 sec/batch
# Epoch: 2/20...  Training Step: 6950...  Training loss: 1.9373...  0.0547 sec/batch
# Epoch: 2/20...  Training Step: 7000...  Training loss: 1.6556...  0.0553 sec/batch
# Epoch: 2/20...  Training Step: 7050...  Training loss: 1.6959...  0.0542 sec/batch
# Epoch: 2/20...  Training Step: 7100...  Training loss: 1.6411...  0.0578 sec/batch
# Epoch: 2/20...  Training Step: 7150...  Training loss: 1.5959...  0.0581 sec/batch
# Epoch: 2/20...  Training Step: 7200...  Training loss: 1.7292...  0.0543 sec/batch
# Epoch: 2/20...  Training Step: 7250...  Training loss: 1.6198...  0.0568 sec/batch
# Epoch: 2/20...  Training Step: 7300...  Training loss: 1.7458...  0.0554 sec/batch
# Epoch: 2/20...  Training Step: 7350...  Training loss: 1.6203...  0.0535 sec/batch
# Epoch: 2/20...  Training Step: 7400...  Training loss: 1.5402...  0.0547 sec/batch
# Epoch: 2/20...  Training Step: 7450...  Training loss: 1.5594...  0.0540 sec/batch
# Epoch: 2/20...  Training Step: 7500...  Training loss: 1.5598...  0.0544 sec/batch
# Epoch: 2/20...  Training Step: 7550...  Training loss: 1.6099...  0.0543 sec/batch
# Epoch: 2/20...  Training Step: 7600...  Training loss: 1.7018...  0.0539 sec/batch
# Epoch: 2/20...  Training Step: 7650...  Training loss: 1.8427...  0.0550 sec/batch
# Epoch: 2/20...  Training Step: 7700...  Training loss: 1.9237...  0.0542 sec/batch
# Epoch: 2/20...  Training Step: 7750...  Training loss: 1.9530...  0.0542 sec/batch
# Epoch: 2/20...  Training Step: 7800...  Training loss: 1.8228...  0.0529 sec/batch
# Epoch: 2/20...  Training Step: 7850...  Training loss: 1.7264...  0.0536 sec/batch
# Epoch: 2/20...  Training Step: 7900...  Training loss: 1.7853...  0.0537 sec/batch
# Epoch: 3/20...  Training Step: 7950...  Training loss: 1.6871...  0.0534 sec/batch
# Epoch: 3/20...  Training Step: 8000...  Training loss: 1.7165...  0.0546 sec/batch
# Epoch: 3/20...  Training Step: 8050...  Training loss: 1.7165...  0.0550 sec/batch
# Epoch: 3/20...  Training Step: 8100...  Training loss: 1.8776...  0.0559 sec/batch
# Epoch: 3/20...  Training Step: 8150...  Training loss: 1.6819...  0.0541 sec/batch
# Epoch: 3/20...  Training Step: 8200...  Training loss: 1.6396...  0.0547 sec/batch
# Epoch: 3/20...  Training Step: 8250...  Training loss: 1.7547...  0.0544 sec/batch
# Epoch: 3/20...  Training Step: 8300...  Training loss: 1.8220...  0.0565 sec/batch
# Epoch: 3/20...  Training Step: 8350...  Training loss: 1.7727...  0.0564 sec/batch
# Epoch: 3/20...  Training Step: 8400...  Training loss: 1.8631...  0.0569 sec/batch
# Epoch: 3/20...  Training Step: 8450...  Training loss: 1.7495...  0.0531 sec/batch
# Epoch: 3/20...  Training Step: 8500...  Training loss: 1.7432...  0.0537 sec/batch
# Epoch: 3/20...  Training Step: 8550...  Training loss: 1.6790...  0.0574 sec/batch
# Epoch: 3/20...  Training Step: 8600...  Training loss: 1.7300...  0.0541 sec/batch
# Epoch: 3/20...  Training Step: 8650...  Training loss: 1.7391...  0.0532 sec/batch
# Epoch: 3/20...  Training Step: 8700...  Training loss: 1.6301...  0.0545 sec/batch
# Epoch: 3/20...  Training Step: 8750...  Training loss: 1.6468...  0.0582 sec/batch
# Epoch: 3/20...  Training Step: 8800...  Training loss: 1.8516...  0.0534 sec/batch
# Epoch: 3/20...  Training Step: 8850...  Training loss: 1.7285...  0.0535 sec/batch
# Epoch: 3/20...  Training Step: 8900...  Training loss: 1.7510...  0.0540 sec/batch
# Epoch: 3/20...  Training Step: 8950...  Training loss: 1.7649...  0.0531 sec/batch
# Epoch: 3/20...  Training Step: 9000...  Training loss: 1.6187...  0.0541 sec/batch
# Epoch: 3/20...  Training Step: 9050...  Training loss: 1.5846...  0.0553 sec/batch
# Epoch: 3/20...  Training Step: 9100...  Training loss: 1.5194...  0.0538 sec/batch
# Epoch: 3/20...  Training Step: 9150...  Training loss: 1.6484...  0.0537 sec/batch
# Epoch: 3/20...  Training Step: 9200...  Training loss: 1.6576...  0.0561 sec/batch
# Epoch: 3/20...  Training Step: 9250...  Training loss: 1.7618...  0.0547 sec/batch
# Epoch: 3/20...  Training Step: 9300...  Training loss: 1.5557...  0.0585 sec/batch
# Epoch: 3/20...  Training Step: 9350...  Training loss: 1.7563...  0.0548 sec/batch
# Epoch: 3/20...  Training Step: 9400...  Training loss: 1.7143...  0.0589 sec/batch
# Epoch: 3/20...  Training Step: 9450...  Training loss: 1.6449...  0.0551 sec/batch
# Epoch: 3/20...  Training Step: 9500...  Training loss: 1.7303...  0.0565 sec/batch
# Epoch: 3/20...  Training Step: 9550...  Training loss: 1.7864...  0.0568 sec/batch
# Epoch: 3/20...  Training Step: 9600...  Training loss: 1.6119...  0.0546 sec/batch
# Epoch: 3/20...  Training Step: 9650...  Training loss: 1.6156...  0.0563 sec/batch
# Epoch: 3/20...  Training Step: 9700...  Training loss: 1.6081...  0.0548 sec/batch
# Epoch: 3/20...  Training Step: 9750...  Training loss: 1.4496...  0.0549 sec/batch
# Epoch: 3/20...  Training Step: 9800...  Training loss: 1.7307...  0.0549 sec/batch
# Epoch: 3/20...  Training Step: 9850...  Training loss: 1.6174...  0.0563 sec/batch
# Epoch: 3/20...  Training Step: 9900...  Training loss: 1.7718...  0.0529 sec/batch
# Epoch: 3/20...  Training Step: 9950...  Training loss: 1.7185...  0.0567 sec/batch
# Epoch: 3/20...  Training Step: 10000...  Training loss: 1.5923...  0.0536 sec/batch
# Epoch: 3/20...  Training Step: 10050...  Training loss: 1.6714...  0.0544 sec/batch
# Epoch: 3/20...  Training Step: 10100...  Training loss: 1.6720...  0.0561 sec/batch
# Epoch: 3/20...  Training Step: 10150...  Training loss: 1.7469...  0.0551 sec/batch
# Epoch: 3/20...  Training Step: 10200...  Training loss: 1.8198...  0.0546 sec/batch
# Epoch: 3/20...  Training Step: 10250...  Training loss: 1.6869...  0.0561 sec/batch
# Epoch: 3/20...  Training Step: 10300...  Training loss: 1.7992...  0.0550 sec/batch
# Epoch: 3/20...  Training Step: 10350...  Training loss: 1.6059...  0.0534 sec/batch
# Epoch: 3/20...  Training Step: 10400...  Training loss: 1.8074...  0.0556 sec/batch
# Epoch: 3/20...  Training Step: 10450...  Training loss: 1.7016...  0.0539 sec/batch
# Epoch: 3/20...  Training Step: 10500...  Training loss: 1.5010...  0.0534 sec/batch
# Epoch: 3/20...  Training Step: 10550...  Training loss: 1.7671...  0.0548 sec/batch
# Epoch: 3/20...  Training Step: 10600...  Training loss: 1.7637...  0.0541 sec/batch
# Epoch: 3/20...  Training Step: 10650...  Training loss: 1.6618...  0.0543 sec/batch
# Epoch: 3/20...  Training Step: 10700...  Training loss: 1.7194...  0.0547 sec/batch
# Epoch: 3/20...  Training Step: 10750...  Training loss: 1.7716...  0.0542 sec/batch
# Epoch: 3/20...  Training Step: 10800...  Training loss: 1.6231...  0.0554 sec/batch
# Epoch: 3/20...  Training Step: 10850...  Training loss: 1.6571...  0.0546 sec/batch
# Epoch: 3/20...  Training Step: 10900...  Training loss: 1.6886...  0.0542 sec/batch
# Epoch: 3/20...  Training Step: 10950...  Training loss: 1.7919...  0.0607 sec/batch
# Epoch: 3/20...  Training Step: 11000...  Training loss: 1.6628...  0.0541 sec/batch
# Epoch: 3/20...  Training Step: 11050...  Training loss: 1.6767...  0.0554 sec/batch
# Epoch: 3/20...  Training Step: 11100...  Training loss: 1.5816...  0.0569 sec/batch
# Epoch: 3/20...  Training Step: 11150...  Training loss: 1.5909...  0.0571 sec/batch
# Epoch: 3/20...  Training Step: 11200...  Training loss: 1.6294...  0.0547 sec/batch
# Epoch: 3/20...  Training Step: 11250...  Training loss: 1.6892...  0.0544 sec/batch
# Epoch: 3/20...  Training Step: 11300...  Training loss: 1.5837...  0.0554 sec/batch
# Epoch: 3/20...  Training Step: 11350...  Training loss: 1.7380...  0.0542 sec/batch
# Epoch: 3/20...  Training Step: 11400...  Training loss: 1.6090...  0.0570 sec/batch
# Epoch: 3/20...  Training Step: 11450...  Training loss: 1.6509...  0.0548 sec/batch
# Epoch: 3/20...  Training Step: 11500...  Training loss: 1.6671...  0.0544 sec/batch
# Epoch: 3/20...  Training Step: 11550...  Training loss: 1.7003...  0.0533 sec/batch
# Epoch: 3/20...  Training Step: 11600...  Training loss: 1.7744...  0.0539 sec/batch
# Epoch: 3/20...  Training Step: 11650...  Training loss: 1.6500...  0.0537 sec/batch
# Epoch: 3/20...  Training Step: 11700...  Training loss: 1.6413...  0.0536 sec/batch
# Epoch: 3/20...  Training Step: 11750...  Training loss: 1.7548...  0.0541 sec/batch
# Epoch: 3/20...  Training Step: 11800...  Training loss: 1.6883...  0.0546 sec/batch
# Epoch: 3/20...  Training Step: 11850...  Training loss: 1.9905...  0.0541 sec/batch
# Epoch: 3/20...  Training Step: 11900...  Training loss: 1.7220...  0.0562 sec/batch
# Epoch: 4/20...  Training Step: 11950...  Training loss: 1.7548...  0.0545 sec/batch
# Epoch: 4/20...  Training Step: 12000...  Training loss: 1.7456...  0.0547 sec/batch
# Epoch: 4/20...  Training Step: 12050...  Training loss: 1.6391...  0.0550 sec/batch
# Epoch: 4/20...  Training Step: 12100...  Training loss: 1.6966...  0.0543 sec/batch
# Epoch: 4/20...  Training Step: 12150...  Training loss: 1.7320...  0.0548 sec/batch
# Epoch: 4/20...  Training Step: 12200...  Training loss: 1.6760...  0.0553 sec/batch
# Epoch: 4/20...  Training Step: 12250...  Training loss: 1.6924...  0.0554 sec/batch
# Epoch: 4/20...  Training Step: 12300...  Training loss: 1.5983...  0.0556 sec/batch
# Epoch: 4/20...  Training Step: 12350...  Training loss: 1.6996...  0.0546 sec/batch
# Epoch: 4/20...  Training Step: 12400...  Training loss: 1.6441...  0.0530 sec/batch
# Epoch: 4/20...  Training Step: 12450...  Training loss: 1.4992...  0.0532 sec/batch
# Epoch: 4/20...  Training Step: 12500...  Training loss: 1.8197...  0.0536 sec/batch
# Epoch: 4/20...  Training Step: 12550...  Training loss: 1.5304...  0.0552 sec/batch
# Epoch: 4/20...  Training Step: 12600...  Training loss: 1.5737...  0.0563 sec/batch
# Epoch: 4/20...  Training Step: 12650...  Training loss: 1.5718...  0.0568 sec/batch
# Epoch: 4/20...  Training Step: 12700...  Training loss: 1.6505...  0.0571 sec/batch
# Epoch: 4/20...  Training Step: 12750...  Training loss: 1.6650...  0.0546 sec/batch
# Epoch: 4/20...  Training Step: 12800...  Training loss: 1.5861...  0.0542 sec/batch
# Epoch: 4/20...  Training Step: 12850...  Training loss: 1.6203...  0.0544 sec/batch
# Epoch: 4/20...  Training Step: 12900...  Training loss: 1.5461...  0.0542 sec/batch
# Epoch: 4/20...  Training Step: 12950...  Training loss: 1.6272...  0.0545 sec/batch
# Epoch: 4/20...  Training Step: 13000...  Training loss: 1.7447...  0.0540 sec/batch
# Epoch: 4/20...  Training Step: 13050...  Training loss: 1.7862...  0.0559 sec/batch
# Epoch: 4/20...  Training Step: 13100...  Training loss: 1.5792...  0.0559 sec/batch
# Epoch: 4/20...  Training Step: 13150...  Training loss: 1.5360...  0.0550 sec/batch
# Epoch: 4/20...  Training Step: 13200...  Training loss: 1.8418...  0.0563 sec/batch
# Epoch: 4/20...  Training Step: 13250...  Training loss: 1.5973...  0.0550 sec/batch
# Epoch: 4/20...  Training Step: 13300...  Training loss: 1.6189...  0.0538 sec/batch
# Epoch: 4/20...  Training Step: 13350...  Training loss: 1.6160...  0.0558 sec/batch
# Epoch: 4/20...  Training Step: 13400...  Training loss: 1.7038...  0.0560 sec/batch
# Epoch: 4/20...  Training Step: 13450...  Training loss: 1.7299...  0.0560 sec/batch
# Epoch: 4/20...  Training Step: 13500...  Training loss: 1.6307...  0.0595 sec/batch
# Epoch: 4/20...  Training Step: 13550...  Training loss: 1.7011...  0.0554 sec/batch
# Epoch: 4/20...  Training Step: 13600...  Training loss: 1.6496...  0.0543 sec/batch
# Epoch: 4/20...  Training Step: 13650...  Training loss: 1.6868...  0.0544 sec/batch
# Epoch: 4/20...  Training Step: 13700...  Training loss: 1.5793...  0.0569 sec/batch
# Epoch: 4/20...  Training Step: 13750...  Training loss: 1.7216...  0.0533 sec/batch
# Epoch: 4/20...  Training Step: 13800...  Training loss: 1.5968...  0.0536 sec/batch
# Epoch: 4/20...  Training Step: 13850...  Training loss: 1.8949...  0.0541 sec/batch
# Epoch: 4/20...  Training Step: 13900...  Training loss: 1.6012...  0.0540 sec/batch
# Epoch: 4/20...  Training Step: 13950...  Training loss: 1.7302...  0.0532 sec/batch
# Epoch: 4/20...  Training Step: 14000...  Training loss: 1.6480...  0.0569 sec/batch
# Epoch: 4/20...  Training Step: 14050...  Training loss: 1.6655...  0.0550 sec/batch
# Epoch: 4/20...  Training Step: 14100...  Training loss: 1.6135...  0.0550 sec/batch
# Epoch: 4/20...  Training Step: 14150...  Training loss: 1.8844...  0.0547 sec/batch
# Epoch: 4/20...  Training Step: 14200...  Training loss: 1.6380...  0.0582 sec/batch
# Epoch: 4/20...  Training Step: 14250...  Training loss: 1.6982...  0.0550 sec/batch
# Epoch: 4/20...  Training Step: 14300...  Training loss: 1.6573...  0.0583 sec/batch
# Epoch: 4/20...  Training Step: 14350...  Training loss: 1.6395...  0.0558 sec/batch
# Epoch: 4/20...  Training Step: 14400...  Training loss: 1.7163...  0.0548 sec/batch
# Epoch: 4/20...  Training Step: 14450...  Training loss: 1.7585...  0.0539 sec/batch
# Epoch: 4/20...  Training Step: 14500...  Training loss: 1.6744...  0.0532 sec/batch
# Epoch: 4/20...  Training Step: 14550...  Training loss: 1.5745...  0.0553 sec/batch
# Epoch: 4/20...  Training Step: 14600...  Training loss: 1.7244...  0.0543 sec/batch
# Epoch: 4/20...  Training Step: 14650...  Training loss: 1.6163...  0.0532 sec/batch
# Epoch: 4/20...  Training Step: 14700...  Training loss: 1.5847...  0.0542 sec/batch
# Epoch: 4/20...  Training Step: 14750...  Training loss: 1.7142...  0.0532 sec/batch
# Epoch: 4/20...  Training Step: 14800...  Training loss: 1.5721...  0.0536 sec/batch
# Epoch: 4/20...  Training Step: 14850...  Training loss: 1.6686...  0.0556 sec/batch
# Epoch: 4/20...  Training Step: 14900...  Training loss: 1.6117...  0.0552 sec/batch
# Epoch: 4/20...  Training Step: 14950...  Training loss: 1.7773...  0.0551 sec/batch
# Epoch: 4/20...  Training Step: 15000...  Training loss: 1.6401...  0.0556 sec/batch
# Epoch: 4/20...  Training Step: 15050...  Training loss: 1.7563...  0.0547 sec/batch
# Epoch: 4/20...  Training Step: 15100...  Training loss: 1.6353...  0.0544 sec/batch
# Epoch: 4/20...  Training Step: 15150...  Training loss: 1.5578...  0.0540 sec/batch
# Epoch: 4/20...  Training Step: 15200...  Training loss: 1.7540...  0.0548 sec/batch
# Epoch: 4/20...  Training Step: 15250...  Training loss: 1.5865...  0.0547 sec/batch
# Epoch: 4/20...  Training Step: 15300...  Training loss: 1.6702...  0.0562 sec/batch
# Epoch: 4/20...  Training Step: 15350...  Training loss: 1.6855...  0.0543 sec/batch
# Epoch: 4/20...  Training Step: 15400...  Training loss: 1.8211...  0.0533 sec/batch
# Epoch: 4/20...  Training Step: 15450...  Training loss: 1.5965...  0.0537 sec/batch
# Epoch: 4/20...  Training Step: 15500...  Training loss: 1.5592...  0.0556 sec/batch
# Epoch: 4/20...  Training Step: 15550...  Training loss: 1.5767...  0.0540 sec/batch
# Epoch: 4/20...  Training Step: 15600...  Training loss: 1.6394...  0.0546 sec/batch
# Epoch: 4/20...  Training Step: 15650...  Training loss: 1.6791...  0.0582 sec/batch
# Epoch: 4/20...  Training Step: 15700...  Training loss: 1.6051...  0.0569 sec/batch
# Epoch: 4/20...  Training Step: 15750...  Training loss: 1.9080...  0.0547 sec/batch
# Epoch: 4/20...  Training Step: 15800...  Training loss: 1.7414...  0.0541 sec/batch
# Epoch: 4/20...  Training Step: 15850...  Training loss: 1.5983...  0.0538 sec/batch
# Epoch: 5/20...  Training Step: 15900...  Training loss: 1.7358...  0.0544 sec/batch
# Epoch: 5/20...  Training Step: 15950...  Training loss: 1.6210...  0.0574 sec/batch
# Epoch: 5/20...  Training Step: 16000...  Training loss: 1.5815...  0.0558 sec/batch
# Epoch: 5/20...  Training Step: 16050...  Training loss: 1.6565...  0.0544 sec/batch
# Epoch: 5/20...  Training Step: 16100...  Training loss: 1.6455...  0.0537 sec/batch
# Epoch: 5/20...  Training Step: 16150...  Training loss: 1.7012...  0.0536 sec/batch
# Epoch: 5/20...  Training Step: 16200...  Training loss: 1.6996...  0.0577 sec/batch
# Epoch: 5/20...  Training Step: 16250...  Training loss: 1.7362...  0.0561 sec/batch
# Epoch: 5/20...  Training Step: 16300...  Training loss: 1.6532...  0.0543 sec/batch
# Epoch: 5/20...  Training Step: 16350...  Training loss: 1.6664...  0.0539 sec/batch
# Epoch: 5/20...  Training Step: 16400...  Training loss: 1.5864...  0.0564 sec/batch
# Epoch: 5/20...  Training Step: 16450...  Training loss: 1.6683...  0.0539 sec/batch
# Epoch: 5/20...  Training Step: 16500...  Training loss: 1.5226...  0.0565 sec/batch
# Epoch: 5/20...  Training Step: 16550...  Training loss: 1.7441...  0.0557 sec/batch
# Epoch: 5/20...  Training Step: 16600...  Training loss: 1.7010...  0.0544 sec/batch
# Epoch: 5/20...  Training Step: 16650...  Training loss: 1.6317...  0.0598 sec/batch
# Epoch: 5/20...  Training Step: 16700...  Training loss: 1.6557...  0.0558 sec/batch
# Epoch: 5/20...  Training Step: 16750...  Training loss: 1.6775...  0.0568 sec/batch
# Epoch: 5/20...  Training Step: 16800...  Training loss: 1.5249...  0.0588 sec/batch
# Epoch: 5/20...  Training Step: 16850...  Training loss: 1.4866...  0.0544 sec/batch
# Epoch: 5/20...  Training Step: 16900...  Training loss: 1.4741...  0.0606 sec/batch
# Epoch: 5/20...  Training Step: 16950...  Training loss: 1.6097...  0.0569 sec/batch
# Epoch: 5/20...  Training Step: 17000...  Training loss: 1.4459...  0.0542 sec/batch
# Epoch: 5/20...  Training Step: 17050...  Training loss: 1.6059...  0.0570 sec/batch
# Epoch: 5/20...  Training Step: 17100...  Training loss: 1.5075...  0.0590 sec/batch
# Epoch: 5/20...  Training Step: 17150...  Training loss: 1.6946...  0.0550 sec/batch
# Epoch: 5/20...  Training Step: 17200...  Training loss: 1.6667...  0.0583 sec/batch
# Epoch: 5/20...  Training Step: 17250...  Training loss: 1.6836...  0.0542 sec/batch
# Epoch: 5/20...  Training Step: 17300...  Training loss: 1.6648...  0.0541 sec/batch
# Epoch: 5/20...  Training Step: 17350...  Training loss: 1.5683...  0.0554 sec/batch
# Epoch: 5/20...  Training Step: 17400...  Training loss: 1.5882...  0.0581 sec/batch
# Epoch: 5/20...  Training Step: 17450...  Training loss: 1.7180...  0.0563 sec/batch
# Epoch: 5/20...  Training Step: 17500...  Training loss: 1.7477...  0.0569 sec/batch
# Epoch: 5/20...  Training Step: 17550...  Training loss: 1.6809...  0.0530 sec/batch
# Epoch: 5/20...  Training Step: 17600...  Training loss: 1.6095...  0.0533 sec/batch
# Epoch: 5/20...  Training Step: 17650...  Training loss: 1.6352...  0.0535 sec/batch
# Epoch: 5/20...  Training Step: 17700...  Training loss: 1.6305...  0.0571 sec/batch
# Epoch: 5/20...  Training Step: 17750...  Training loss: 1.4860...  0.0549 sec/batch
# Epoch: 5/20...  Training Step: 17800...  Training loss: 1.6496...  0.0561 sec/batch
# Epoch: 5/20...  Training Step: 17850...  Training loss: 1.6033...  0.0575 sec/batch
# Epoch: 5/20...  Training Step: 17900...  Training loss: 1.4730...  0.0554 sec/batch
# Epoch: 5/20...  Training Step: 17950...  Training loss: 1.5776...  0.0545 sec/batch
# Epoch: 5/20...  Training Step: 18000...  Training loss: 1.4273...  0.0543 sec/batch
# Epoch: 5/20...  Training Step: 18050...  Training loss: 1.5853...  0.0545 sec/batch
# Epoch: 5/20...  Training Step: 18100...  Training loss: 1.7080...  0.0578 sec/batch
# Epoch: 5/20...  Training Step: 18150...  Training loss: 1.5165...  0.0538 sec/batch
# Epoch: 5/20...  Training Step: 18200...  Training loss: 1.5200...  0.0548 sec/batch
# Epoch: 5/20...  Training Step: 18250...  Training loss: 1.5142...  0.0559 sec/batch
# Epoch: 5/20...  Training Step: 18300...  Training loss: 1.7303...  0.0533 sec/batch
# Epoch: 5/20...  Training Step: 18350...  Training loss: 1.6216...  0.0559 sec/batch
# Epoch: 5/20...  Training Step: 18400...  Training loss: 1.7299...  0.0532 sec/batch
# Epoch: 5/20...  Training Step: 18450...  Training loss: 1.5495...  0.0562 sec/batch
# Epoch: 5/20...  Training Step: 18500...  Training loss: 1.5295...  0.0558 sec/batch
# Epoch: 5/20...  Training Step: 18550...  Training loss: 1.6599...  0.0538 sec/batch
# Epoch: 5/20...  Training Step: 18600...  Training loss: 1.5136...  0.0533 sec/batch
# Epoch: 5/20...  Training Step: 18650...  Training loss: 1.6312...  0.0535 sec/batch
# Epoch: 5/20...  Training Step: 18700...  Training loss: 1.7905...  0.0531 sec/batch
# Epoch: 5/20...  Training Step: 18750...  Training loss: 1.6346...  0.0534 sec/batch
# Epoch: 5/20...  Training Step: 18800...  Training loss: 1.7620...  0.0566 sec/batch
# Epoch: 5/20...  Training Step: 18850...  Training loss: 1.5122...  0.0569 sec/batch
# Epoch: 5/20...  Training Step: 18900...  Training loss: 1.7290...  0.0541 sec/batch
# Epoch: 5/20...  Training Step: 18950...  Training loss: 1.5962...  0.0545 sec/batch
# Epoch: 5/20...  Training Step: 19000...  Training loss: 1.5261...  0.0540 sec/batch
# Epoch: 5/20...  Training Step: 19050...  Training loss: 1.7062...  0.0535 sec/batch
# Epoch: 5/20...  Training Step: 19100...  Training loss: 1.6144...  0.0570 sec/batch
# Epoch: 5/20...  Training Step: 19150...  Training loss: 1.7022...  0.0551 sec/batch
# Epoch: 5/20...  Training Step: 19200...  Training loss: 1.6504...  0.0536 sec/batch
# Epoch: 5/20...  Training Step: 19250...  Training loss: 1.5349...  0.0560 sec/batch
# Epoch: 5/20...  Training Step: 19300...  Training loss: 1.7722...  0.0551 sec/batch
# Epoch: 5/20...  Training Step: 19350...  Training loss: 1.5904...  0.0535 sec/batch
# Epoch: 5/20...  Training Step: 19400...  Training loss: 1.6268...  0.0555 sec/batch
# Epoch: 5/20...  Training Step: 19450...  Training loss: 1.3732...  0.0543 sec/batch
# Epoch: 5/20...  Training Step: 19500...  Training loss: 1.6156...  0.0534 sec/batch
# Epoch: 5/20...  Training Step: 19550...  Training loss: 1.6902...  0.0545 sec/batch
# Epoch: 5/20...  Training Step: 19600...  Training loss: 1.5999...  0.0541 sec/batch
# Epoch: 5/20...  Training Step: 19650...  Training loss: 1.5827...  0.0541 sec/batch
# Epoch: 5/20...  Training Step: 19700...  Training loss: 2.0457...  0.0554 sec/batch
# Epoch: 5/20...  Training Step: 19750...  Training loss: 1.7644...  0.0537 sec/batch
# Epoch: 5/20...  Training Step: 19800...  Training loss: 1.9571...  0.0543 sec/batch
# Epoch: 5/20...  Training Step: 19850...  Training loss: 1.9354...  0.0540 sec/batch
# Epoch: 6/20...  Training Step: 19900...  Training loss: 1.8005...  0.0534 sec/batch
# Epoch: 6/20...  Training Step: 19950...  Training loss: 1.5992...  0.0563 sec/batch
# Epoch: 6/20...  Training Step: 20000...  Training loss: 1.4311...  0.0543 sec/batch
# Epoch: 6/20...  Training Step: 20050...  Training loss: 1.6842...  0.0565 sec/batch
# Epoch: 6/20...  Training Step: 20100...  Training loss: 1.6143...  0.0541 sec/batch
# Epoch: 6/20...  Training Step: 20150...  Training loss: 1.5495...  0.0539 sec/batch
# Epoch: 6/20...  Training Step: 20200...  Training loss: 1.6508...  0.0546 sec/batch
# Epoch: 6/20...  Training Step: 20250...  Training loss: 1.6698...  0.0540 sec/batch
# Epoch: 6/20...  Training Step: 20300...  Training loss: 1.6884...  0.0537 sec/batch
# Epoch: 6/20...  Training Step: 20350...  Training loss: 1.7165...  0.0535 sec/batch
# Epoch: 6/20...  Training Step: 20400...  Training loss: 1.5091...  0.0555 sec/batch
# Epoch: 6/20...  Training Step: 20450...  Training loss: 1.5512...  0.0534 sec/batch
# Epoch: 6/20...  Training Step: 20500...  Training loss: 1.4306...  0.0541 sec/batch
# Epoch: 6/20...  Training Step: 20550...  Training loss: 1.5126...  0.0534 sec/batch
# Epoch: 6/20...  Training Step: 20600...  Training loss: 1.5612...  0.0536 sec/batch
# Epoch: 6/20...  Training Step: 20650...  Training loss: 1.6151...  0.0527 sec/batch
# Epoch: 6/20...  Training Step: 20700...  Training loss: 1.7674...  0.0531 sec/batch
# Epoch: 6/20...  Training Step: 20750...  Training loss: 1.6812...  0.0545 sec/batch
# Epoch: 6/20...  Training Step: 20800...  Training loss: 1.6389...  0.0537 sec/batch
# Epoch: 6/20...  Training Step: 20850...  Training loss: 1.5788...  0.0540 sec/batch
# Epoch: 6/20...  Training Step: 20900...  Training loss: 1.6365...  0.0549 sec/batch
# Epoch: 6/20...  Training Step: 20950...  Training loss: 1.5584...  0.0539 sec/batch
# Epoch: 6/20...  Training Step: 21000...  Training loss: 1.6150...  0.0552 sec/batch
# Epoch: 6/20...  Training Step: 21050...  Training loss: 1.5671...  0.0571 sec/batch
# Epoch: 6/20...  Training Step: 21100...  Training loss: 1.4553...  0.0545 sec/batch
# Epoch: 6/20...  Training Step: 21150...  Training loss: 1.5673...  0.0543 sec/batch
# Epoch: 6/20...  Training Step: 21200...  Training loss: 1.5394...  0.0539 sec/batch
# Epoch: 6/20...  Training Step: 21250...  Training loss: 1.7992...  0.0576 sec/batch
# Epoch: 6/20...  Training Step: 21300...  Training loss: 1.6227...  0.0556 sec/batch
# Epoch: 6/20...  Training Step: 21350...  Training loss: 1.6724...  0.0541 sec/batch
# Epoch: 6/20...  Training Step: 21400...  Training loss: 1.6008...  0.0535 sec/batch
# Epoch: 6/20...  Training Step: 21450...  Training loss: 1.6600...  0.0536 sec/batch
# Epoch: 6/20...  Training Step: 21500...  Training loss: 1.5515...  0.0538 sec/batch
# Epoch: 6/20...  Training Step: 21550...  Training loss: 1.6212...  0.0570 sec/batch
# Epoch: 6/20...  Training Step: 21600...  Training loss: 1.6935...  0.0584 sec/batch
# Epoch: 6/20...  Training Step: 21650...  Training loss: 1.6594...  0.0558 sec/batch
# Epoch: 6/20...  Training Step: 21700...  Training loss: 1.7760...  0.0552 sec/batch
# Epoch: 6/20...  Training Step: 21750...  Training loss: 1.4524...  0.0546 sec/batch
# Epoch: 6/20...  Training Step: 21800...  Training loss: 1.5326...  0.0541 sec/batch
# Epoch: 6/20...  Training Step: 21850...  Training loss: 1.6406...  0.0544 sec/batch
# Epoch: 6/20...  Training Step: 21900...  Training loss: 1.7668...  0.0540 sec/batch
# Epoch: 6/20...  Training Step: 21950...  Training loss: 1.6144...  0.0539 sec/batch
# Epoch: 6/20...  Training Step: 22000...  Training loss: 1.5760...  0.0531 sec/batch
# Epoch: 6/20...  Training Step: 22050...  Training loss: 1.6037...  0.0555 sec/batch
# Epoch: 6/20...  Training Step: 22100...  Training loss: 1.5968...  0.0534 sec/batch
# Epoch: 6/20...  Training Step: 22150...  Training loss: 1.5451...  0.0539 sec/batch
# Epoch: 6/20...  Training Step: 22200...  Training loss: 1.7453...  0.0541 sec/batch
# Epoch: 6/20...  Training Step: 22250...  Training loss: 1.6820...  0.0543 sec/batch
# Epoch: 6/20...  Training Step: 22300...  Training loss: 1.7664...  0.0568 sec/batch
# Epoch: 6/20...  Training Step: 22350...  Training loss: 1.5891...  0.0561 sec/batch
# Epoch: 6/20...  Training Step: 22400...  Training loss: 1.6762...  0.0551 sec/batch
# Epoch: 6/20...  Training Step: 22450...  Training loss: 1.5580...  0.0560 sec/batch
# Epoch: 6/20...  Training Step: 22500...  Training loss: 1.7293...  0.0546 sec/batch
# Epoch: 6/20...  Training Step: 22550...  Training loss: 1.6554...  0.0574 sec/batch
# Epoch: 6/20...  Training Step: 22600...  Training loss: 1.5751...  0.0570 sec/batch
# Epoch: 6/20...  Training Step: 22650...  Training loss: 1.4991...  0.0545 sec/batch
# Epoch: 6/20...  Training Step: 22700...  Training loss: 1.7306...  0.0553 sec/batch
# Epoch: 6/20...  Training Step: 22750...  Training loss: 1.4667...  0.0549 sec/batch
# Epoch: 6/20...  Training Step: 22800...  Training loss: 1.4714...  0.0554 sec/batch
# Epoch: 6/20...  Training Step: 22850...  Training loss: 1.5960...  0.0535 sec/batch
# Epoch: 6/20...  Training Step: 22900...  Training loss: 1.7033...  0.0561 sec/batch
# Epoch: 6/20...  Training Step: 22950...  Training loss: 1.6142...  0.0556 sec/batch
# Epoch: 6/20...  Training Step: 23000...  Training loss: 1.5235...  0.0538 sec/batch
# Epoch: 6/20...  Training Step: 23050...  Training loss: 1.7876...  0.0526 sec/batch
# Epoch: 6/20...  Training Step: 23100...  Training loss: 1.6714...  0.0542 sec/batch
# Epoch: 6/20...  Training Step: 23150...  Training loss: 1.6669...  0.0534 sec/batch
# Epoch: 6/20...  Training Step: 23200...  Training loss: 1.4453...  0.0547 sec/batch
# Epoch: 6/20...  Training Step: 23250...  Training loss: 1.6086...  0.0570 sec/batch
# Epoch: 6/20...  Training Step: 23300...  Training loss: 1.5581...  0.0567 sec/batch
# Epoch: 6/20...  Training Step: 23350...  Training loss: 1.5204...  0.0550 sec/batch
# Epoch: 6/20...  Training Step: 23400...  Training loss: 1.7123...  0.0605 sec/batch
# Epoch: 6/20...  Training Step: 23450...  Training loss: 1.6201...  0.0539 sec/batch
# Epoch: 6/20...  Training Step: 23500...  Training loss: 1.7587...  0.0551 sec/batch
# Epoch: 6/20...  Training Step: 23550...  Training loss: 1.5538...  0.0571 sec/batch
# Epoch: 6/20...  Training Step: 23600...  Training loss: 1.6623...  0.0558 sec/batch
# Epoch: 6/20...  Training Step: 23650...  Training loss: 1.5660...  0.0545 sec/batch
# Epoch: 6/20...  Training Step: 23700...  Training loss: 1.5574...  0.0569 sec/batch
# Epoch: 6/20...  Training Step: 23750...  Training loss: 1.7612...  0.0583 sec/batch
# Epoch: 6/20...  Training Step: 23800...  Training loss: 1.5504...  0.0538 sec/batch
# Epoch: 7/20...  Training Step: 23850...  Training loss: 1.6020...  0.0554 sec/batch
# Epoch: 7/20...  Training Step: 23900...  Training loss: 1.5967...  0.0526 sec/batch
# Epoch: 7/20...  Training Step: 23950...  Training loss: 1.5710...  0.0563 sec/batch
# Epoch: 7/20...  Training Step: 24000...  Training loss: 1.5384...  0.0538 sec/batch
# Epoch: 7/20...  Training Step: 24050...  Training loss: 1.6007...  0.0535 sec/batch
# Epoch: 7/20...  Training Step: 24100...  Training loss: 1.6544...  0.0544 sec/batch
# Epoch: 7/20...  Training Step: 24150...  Training loss: 1.7050...  0.0586 sec/batch
# Epoch: 7/20...  Training Step: 24200...  Training loss: 1.6673...  0.0547 sec/batch
# Epoch: 7/20...  Training Step: 24250...  Training loss: 1.6106...  0.0574 sec/batch
# Epoch: 7/20...  Training Step: 24300...  Training loss: 1.6647...  0.0551 sec/batch
# Epoch: 7/20...  Training Step: 24350...  Training loss: 1.6327...  0.0589 sec/batch
# Epoch: 7/20...  Training Step: 24400...  Training loss: 1.7493...  0.0543 sec/batch
# Epoch: 7/20...  Training Step: 24450...  Training loss: 1.7167...  0.0534 sec/batch
# Epoch: 7/20...  Training Step: 24500...  Training loss: 1.7400...  0.0555 sec/batch
# Epoch: 7/20...  Training Step: 24550...  Training loss: 1.4941...  0.0534 sec/batch
# Epoch: 7/20...  Training Step: 24600...  Training loss: 1.7173...  0.0533 sec/batch
# Epoch: 7/20...  Training Step: 24650...  Training loss: 1.5036...  0.0536 sec/batch
# Epoch: 7/20...  Training Step: 24700...  Training loss: 1.5669...  0.0531 sec/batch
# Epoch: 7/20...  Training Step: 24750...  Training loss: 1.6432...  0.0539 sec/batch
# Epoch: 7/20...  Training Step: 24800...  Training loss: 1.5370...  0.0538 sec/batch
# Epoch: 7/20...  Training Step: 24850...  Training loss: 1.6102...  0.0566 sec/batch
# Epoch: 7/20...  Training Step: 24900...  Training loss: 1.4306...  0.0564 sec/batch
# Epoch: 7/20...  Training Step: 24950...  Training loss: 1.4707...  0.0547 sec/batch
# Epoch: 7/20...  Training Step: 25000...  Training loss: 1.5930...  0.0563 sec/batch
# Epoch: 7/20...  Training Step: 25050...  Training loss: 1.6709...  0.0550 sec/batch
# Epoch: 7/20...  Training Step: 25100...  Training loss: 1.4813...  0.0538 sec/batch
# Epoch: 7/20...  Training Step: 25150...  Training loss: 1.7019...  0.0559 sec/batch
# Epoch: 7/20...  Training Step: 25200...  Training loss: 1.5795...  0.0541 sec/batch
# Epoch: 7/20...  Training Step: 25250...  Training loss: 1.6656...  0.0543 sec/batch
# Epoch: 7/20...  Training Step: 25300...  Training loss: 1.6733...  0.0549 sec/batch
# Epoch: 7/20...  Training Step: 25350...  Training loss: 1.6715...  0.0564 sec/batch
# Epoch: 7/20...  Training Step: 25400...  Training loss: 1.5437...  0.0563 sec/batch
# Epoch: 7/20...  Training Step: 25450...  Training loss: 1.7335...  0.0548 sec/batch
# Epoch: 7/20...  Training Step: 25500...  Training loss: 1.5248...  0.0568 sec/batch
# Epoch: 7/20...  Training Step: 25550...  Training loss: 1.4901...  0.0546 sec/batch
# Epoch: 7/20...  Training Step: 25600...  Training loss: 1.5591...  0.0556 sec/batch
# Epoch: 7/20...  Training Step: 25650...  Training loss: 1.6768...  0.0540 sec/batch
# Epoch: 7/20...  Training Step: 25700...  Training loss: 1.6456...  0.0549 sec/batch
# Epoch: 7/20...  Training Step: 25750...  Training loss: 1.5571...  0.0555 sec/batch
# Epoch: 7/20...  Training Step: 25800...  Training loss: 1.5820...  0.0537 sec/batch
# Epoch: 7/20...  Training Step: 25850...  Training loss: 1.4692...  0.0569 sec/batch
# Epoch: 7/20...  Training Step: 25900...  Training loss: 1.5584...  0.0542 sec/batch
# Epoch: 7/20...  Training Step: 25950...  Training loss: 1.6582...  0.0572 sec/batch
# Epoch: 7/20...  Training Step: 26000...  Training loss: 1.7157...  0.0566 sec/batch
# Epoch: 7/20...  Training Step: 26050...  Training loss: 1.5530...  0.0571 sec/batch
# Epoch: 7/20...  Training Step: 26100...  Training loss: 1.5453...  0.0545 sec/batch
# Epoch: 7/20...  Training Step: 26150...  Training loss: 1.5383...  0.0539 sec/batch
# Epoch: 7/20...  Training Step: 26200...  Training loss: 1.6130...  0.0545 sec/batch
# Epoch: 7/20...  Training Step: 26250...  Training loss: 1.5563...  0.0566 sec/batch
# Epoch: 7/20...  Training Step: 26300...  Training loss: 1.6442...  0.0541 sec/batch
# Epoch: 7/20...  Training Step: 26350...  Training loss: 1.5544...  0.0570 sec/batch
# Epoch: 7/20...  Training Step: 26400...  Training loss: 1.7030...  0.0555 sec/batch
# Epoch: 7/20...  Training Step: 26450...  Training loss: 1.7803...  0.0565 sec/batch
# Epoch: 7/20...  Training Step: 26500...  Training loss: 1.4635...  0.0541 sec/batch
# Epoch: 7/20...  Training Step: 26550...  Training loss: 1.5339...  0.0565 sec/batch
# Epoch: 7/20...  Training Step: 26600...  Training loss: 1.5997...  0.0541 sec/batch
# Epoch: 7/20...  Training Step: 26650...  Training loss: 1.6064...  0.0562 sec/batch
# Epoch: 7/20...  Training Step: 26700...  Training loss: 1.5391...  0.0544 sec/batch
# Epoch: 7/20...  Training Step: 26750...  Training loss: 1.4854...  0.0536 sec/batch
# Epoch: 7/20...  Training Step: 26800...  Training loss: 1.8451...  0.0565 sec/batch
# Epoch: 7/20...  Training Step: 26850...  Training loss: 1.5638...  0.0549 sec/batch
# Epoch: 7/20...  Training Step: 26900...  Training loss: 1.6276...  0.0547 sec/batch
# Epoch: 7/20...  Training Step: 26950...  Training loss: 1.5688...  0.0575 sec/batch
# Epoch: 7/20...  Training Step: 27000...  Training loss: 1.5040...  0.0553 sec/batch
# Epoch: 7/20...  Training Step: 27050...  Training loss: 1.7041...  0.0548 sec/batch
# Epoch: 7/20...  Training Step: 27100...  Training loss: 1.4547...  0.0540 sec/batch
# Epoch: 7/20...  Training Step: 27150...  Training loss: 1.7260...  0.0563 sec/batch
# Epoch: 7/20...  Training Step: 27200...  Training loss: 1.4777...  0.0564 sec/batch
# Epoch: 7/20...  Training Step: 27250...  Training loss: 1.4629...  0.0547 sec/batch
# Epoch: 7/20...  Training Step: 27300...  Training loss: 1.4635...  0.0539 sec/batch
# Epoch: 7/20...  Training Step: 27350...  Training loss: 1.5164...  0.0567 sec/batch
# Epoch: 7/20...  Training Step: 27400...  Training loss: 1.4947...  0.0565 sec/batch
# Epoch: 7/20...  Training Step: 27450...  Training loss: 1.5822...  0.0559 sec/batch
# Epoch: 7/20...  Training Step: 27500...  Training loss: 1.6961...  0.0547 sec/batch
# Epoch: 7/20...  Training Step: 27550...  Training loss: 1.7661...  0.0553 sec/batch
# Epoch: 7/20...  Training Step: 27600...  Training loss: 1.8219...  0.0538 sec/batch
# Epoch: 7/20...  Training Step: 27650...  Training loss: 1.6403...  0.0554 sec/batch
# Epoch: 7/20...  Training Step: 27700...  Training loss: 1.6740...  0.0539 sec/batch
# Epoch: 7/20...  Training Step: 27750...  Training loss: 1.6815...  0.0568 sec/batch
# Epoch: 8/20...  Training Step: 27800...  Training loss: 1.6353...  0.0551 sec/batch
# Epoch: 8/20...  Training Step: 27850...  Training loss: 1.6418...  0.0568 sec/batch
# Epoch: 8/20...  Training Step: 27900...  Training loss: 1.6286...  0.0574 sec/batch
# Epoch: 8/20...  Training Step: 27950...  Training loss: 1.7115...  0.0550 sec/batch
# Epoch: 8/20...  Training Step: 28000...  Training loss: 1.5046...  0.0539 sec/batch
# Epoch: 8/20...  Training Step: 28050...  Training loss: 1.5424...  0.0608 sec/batch
# Epoch: 8/20...  Training Step: 28100...  Training loss: 1.6778...  0.0562 sec/batch
# Epoch: 8/20...  Training Step: 28150...  Training loss: 1.7121...  0.0531 sec/batch
# Epoch: 8/20...  Training Step: 28200...  Training loss: 1.6247...  0.0541 sec/batch
# Epoch: 8/20...  Training Step: 28250...  Training loss: 1.7274...  0.0538 sec/batch
# Epoch: 8/20...  Training Step: 28300...  Training loss: 1.6457...  0.0563 sec/batch
# Epoch: 8/20...  Training Step: 28350...  Training loss: 1.5831...  0.0565 sec/batch
# Epoch: 8/20...  Training Step: 28400...  Training loss: 1.5441...  0.0535 sec/batch
# Epoch: 8/20...  Training Step: 28450...  Training loss: 1.5979...  0.0549 sec/batch
# Epoch: 8/20...  Training Step: 28500...  Training loss: 1.6270...  0.0543 sec/batch
# Epoch: 8/20...  Training Step: 28550...  Training loss: 1.5246...  0.0560 sec/batch
# Epoch: 8/20...  Training Step: 28600...  Training loss: 1.5095...  0.0548 sec/batch
# Epoch: 8/20...  Training Step: 28650...  Training loss: 1.7355...  0.0568 sec/batch
# Epoch: 8/20...  Training Step: 28700...  Training loss: 1.6609...  0.0545 sec/batch
# ...
# Epoch: 14/20...  Training Step: 55200...  Training loss: 1.4742...  0.0588 sec/batch
# Epoch: 14/20...  Training Step: 55250...  Training loss: 1.4998...  0.0546 sec/batch
# Epoch: 14/20...  Training Step: 55300...  Training loss: 1.5325...  0.0542 sec/batch
# Epoch: 14/20...  Training Step: 55350...  Training loss: 1.5331...  0.0538 sec/batch
# Epoch: 14/20...  Training Step: 55400...  Training loss: 1.4644...  0.0566 sec/batch
# Epoch: 14/20...  Training Step: 55450...  Training loss: 1.6626...  0.0566 sec/batch
# Epoch: 14/20...  Training Step: 55500...  Training loss: 1.6212...  0.0570 sec/batch
# Epoch: 14/20...  Training Step: 55550...  Training loss: 1.5724...  0.0558 sec/batch
# Epoch: 15/20...  Training Step: 55600...  Training loss: 1.6614...  0.0542 sec/batch
# Epoch: 15/20...  Training Step: 55650...  Training loss: 1.5215...  0.0534 sec/batch
# Epoch: 15/20...  Training Step: 55700...  Training loss: 1.5024...  0.0556 sec/batch
# Epoch: 15/20...  Training Step: 55750...  Training loss: 1.5518...  0.0545 sec/batch
# Epoch: 15/20...  Training Step: 55800...  Training loss: 1.5504...  0.0544 sec/batch
# Epoch: 15/20...  Training Step: 55850...  Training loss: 1.6456...  0.0533 sec/batch
# Epoch: 15/20...  Training Step: 55900...  Training loss: 1.6287...  0.0535 sec/batch
# Epoch: 15/20...  Training Step: 55950...  Training loss: 1.6464...  0.0536 sec/batch
# Epoch: 15/20...  Training Step: 56000...  Training loss: 1.6513...  0.0534 sec/batch
# Epoch: 15/20...  Training Step: 56050...  Training loss: 1.6426...  0.0564 sec/batch
# Epoch: 15/20...  Training Step: 56100...  Training loss: 1.4742...  0.0559 sec/batch
# Epoch: 15/20...  Training Step: 56150...  Training loss: 1.5950...  0.0534 sec/batch
# Epoch: 15/20...  Training Step: 56200...  Training loss: 1.4428...  0.0552 sec/batch
# Epoch: 15/20...  Training Step: 56250...  Training loss: 1.6534...  0.0542 sec/batch
# Epoch: 15/20...  Training Step: 56300...  Training loss: 1.5888...  0.0543 sec/batch
# Epoch: 15/20...  Training Step: 56350...  Training loss: 1.5527...  0.0573 sec/batch
# Epoch: 15/20...  Training Step: 56400...  Training loss: 1.6075...  0.0542 sec/batch
# Epoch: 15/20...  Training Step: 56450...  Training loss: 1.5508...  0.0568 sec/batch
# Epoch: 15/20...  Training Step: 56500...  Training loss: 1.4308...  0.0543 sec/batch
# Epoch: 15/20...  Training Step: 56550...  Training loss: 1.4688...  0.0575 sec/batch
# Epoch: 15/20...  Training Step: 56600...  Training loss: 1.4278...  0.0537 sec/batch
# Epoch: 15/20...  Training Step: 56650...  Training loss: 1.5067...  0.0561 sec/batch
# Epoch: 15/20...  Training Step: 56700...  Training loss: 1.3997...  0.0560 sec/batch
# Epoch: 15/20...  Training Step: 56750...  Training loss: 1.5237...  0.0542 sec/batch
# Epoch: 15/20...  Training Step: 56800...  Training loss: 1.4275...  0.0552 sec/batch
# Epoch: 15/20...  Training Step: 56850...  Training loss: 1.5395...  0.0540 sec/batch
# Epoch: 15/20...  Training Step: 56900...  Training loss: 1.6328...  0.0545 sec/batch
# Epoch: 15/20...  Training Step: 56950...  Training loss: 1.6614...  0.0537 sec/batch
# Epoch: 15/20...  Training Step: 57000...  Training loss: 1.5972...  0.0541 sec/batch
# Epoch: 15/20...  Training Step: 57050...  Training loss: 1.5331...  0.0530 sec/batch
# Epoch: 15/20...  Training Step: 57100...  Training loss: 1.5262...  0.0529 sec/batch
# Epoch: 15/20...  Training Step: 57150...  Training loss: 1.5984...  0.0534 sec/batch
# Epoch: 15/20...  Training Step: 57200...  Training loss: 1.6433...  0.0584 sec/batch
# Epoch: 15/20...  Training Step: 57250...  Training loss: 1.7467...  0.0547 sec/batch
# Epoch: 15/20...  Training Step: 57300...  Training loss: 1.5626...  0.0546 sec/batch
# Epoch: 15/20...  Training Step: 57350...  Training loss: 1.5736...  0.0552 sec/batch
# Epoch: 15/20...  Training Step: 57400...  Training loss: 1.5872...  0.0581 sec/batch
# Epoch: 15/20...  Training Step: 57450...  Training loss: 1.3479...  0.0563 sec/batch
# Epoch: 15/20...  Training Step: 57500...  Training loss: 1.6019...  0.0565 sec/batch
# Epoch: 15/20...  Training Step: 57550...  Training loss: 1.5406...  0.0548 sec/batch
# Epoch: 15/20...  Training Step: 57600...  Training loss: 1.4284...  0.0574 sec/batch
# Epoch: 15/20...  Training Step: 57650...  Training loss: 1.4806...  0.0545 sec/batch
# Epoch: 15/20...  Training Step: 57700...  Training loss: 1.3371...  0.0538 sec/batch
# Epoch: 15/20...  Training Step: 57750...  Training loss: 1.4705...  0.0556 sec/batch
# Epoch: 15/20...  Training Step: 57800...  Training loss: 1.5103...  0.0574 sec/batch
# Epoch: 15/20...  Training Step: 57850...  Training loss: 1.4962...  0.0531 sec/batch
# Epoch: 15/20...  Training Step: 57900...  Training loss: 1.3855...  0.0575 sec/batch
# Epoch: 15/20...  Training Step: 57950...  Training loss: 1.4706...  0.0567 sec/batch
# Epoch: 15/20...  Training Step: 58000...  Training loss: 1.7077...  0.0563 sec/batch
# Epoch: 15/20...  Training Step: 58050...  Training loss: 1.5176...  0.0532 sec/batch
# Epoch: 15/20...  Training Step: 58100...  Training loss: 1.5996...  0.0543 sec/batch
# Epoch: 15/20...  Training Step: 58150...  Training loss: 1.5372...  0.0562 sec/batch
# Epoch: 15/20...  Training Step: 58200...  Training loss: 1.3827...  0.0538 sec/batch
# Epoch: 15/20...  Training Step: 58250...  Training loss: 1.5618...  0.0539 sec/batch
# Epoch: 15/20...  Training Step: 58300...  Training loss: 1.4292...  0.0559 sec/batch
# Epoch: 15/20...  Training Step: 58350...  Training loss: 1.5697...  0.0543 sec/batch
# Epoch: 15/20...  Training Step: 58400...  Training loss: 1.5902...  0.0545 sec/batch
# Epoch: 15/20...  Training Step: 58450...  Training loss: 1.5166...  0.0567 sec/batch
# Epoch: 15/20...  Training Step: 58500...  Training loss: 1.6871...  0.0575 sec/batch
# Epoch: 15/20...  Training Step: 58550...  Training loss: 1.4834...  0.0546 sec/batch
# Epoch: 15/20...  Training Step: 58600...  Training loss: 1.6478...  0.0609 sec/batch
# Epoch: 15/20...  Training Step: 58650...  Training loss: 1.5300...  0.0565 sec/batch
# Epoch: 15/20...  Training Step: 58700...  Training loss: 1.3690...  0.0583 sec/batch
# Epoch: 15/20...  Training Step: 58750...  Training loss: 1.5014...  0.0550 sec/batch
# Epoch: 15/20...  Training Step: 58800...  Training loss: 1.5780...  0.0548 sec/batch
# Epoch: 15/20...  Training Step: 58850...  Training loss: 1.6046...  0.0548 sec/batch
# Epoch: 15/20...  Training Step: 58900...  Training loss: 1.5373...  0.0553 sec/batch
# Epoch: 15/20...  Training Step: 58950...  Training loss: 1.5139...  0.0572 sec/batch
# Epoch: 15/20...  Training Step: 59000...  Training loss: 1.7140...  0.0542 sec/batch
# Epoch: 15/20...  Training Step: 59050...  Training loss: 1.5273...  0.0553 sec/batch
# Epoch: 15/20...  Training Step: 59100...  Training loss: 1.5738...  0.0547 sec/batch
# Epoch: 15/20...  Training Step: 59150...  Training loss: 1.3052...  0.0556 sec/batch
# Epoch: 15/20...  Training Step: 59200...  Training loss: 1.5073...  0.0533 sec/batch
# Epoch: 15/20...  Training Step: 59250...  Training loss: 1.5975...  0.0559 sec/batch
# Epoch: 15/20...  Training Step: 59300...  Training loss: 1.5475...  0.0547 sec/batch
# Epoch: 15/20...  Training Step: 59350...  Training loss: 1.5725...  0.0557 sec/batch
# Epoch: 15/20...  Training Step: 59400...  Training loss: 1.8834...  0.0560 sec/batch
# Epoch: 15/20...  Training Step: 59450...  Training loss: 1.6158...  0.0559 sec/batch
# Epoch: 15/20...  Training Step: 59500...  Training loss: 1.8237...  0.0543 sec/batch
# Epoch: 15/20...  Training Step: 59550...  Training loss: 1.9413...  0.0543 sec/batch
# Epoch: 16/20...  Training Step: 59600...  Training loss: 1.6415...  0.0606 sec/batch
# Epoch: 16/20...  Training Step: 59650...  Training loss: 1.5410...  0.0550 sec/batch
# Epoch: 16/20...  Training Step: 59700...  Training loss: 1.4025...  0.0546 sec/batch
# Epoch: 16/20...  Training Step: 59750...  Training loss: 1.5300...  0.0549 sec/batch
# Epoch: 16/20...  Training Step: 59800...  Training loss: 1.5483...  0.0571 sec/batch
# Epoch: 16/20...  Training Step: 59850...  Training loss: 1.3952...  0.0546 sec/batch
# Epoch: 16/20...  Training Step: 59900...  Training loss: 1.5111...  0.0587 sec/batch
# Epoch: 16/20...  Training Step: 59950...  Training loss: 1.5596...  0.0553 sec/batch
# Epoch: 16/20...  Training Step: 60000...  Training loss: 1.6148...  0.0538 sec/batch
# Epoch: 16/20...  Training Step: 60050...  Training loss: 1.6095...  0.0544 sec/batch
# Epoch: 16/20...  Training Step: 60100...  Training loss: 1.4230...  0.0531 sec/batch
# Epoch: 16/20...  Training Step: 60150...  Training loss: 1.4408...  0.0529 sec/batch
# Epoch: 16/20...  Training Step: 60200...  Training loss: 1.3644...  0.0558 sec/batch
# Epoch: 16/20...  Training Step: 60250...  Training loss: 1.4267...  0.0534 sec/batch
# Epoch: 16/20...  Training Step: 60300...  Training loss: 1.5284...  0.0549 sec/batch
# Epoch: 16/20...  Training Step: 60350...  Training loss: 1.5444...  0.0562 sec/batch
# Epoch: 16/20...  Training Step: 60400...  Training loss: 1.6632...  0.0562 sec/batch
# Epoch: 16/20...  Training Step: 60450...  Training loss: 1.6187...  0.0542 sec/batch
# Epoch: 16/20...  Training Step: 60500...  Training loss: 1.5871...  0.0539 sec/batch
# Epoch: 16/20...  Training Step: 60550...  Training loss: 1.6254...  0.0551 sec/batch
# Epoch: 16/20...  Training Step: 60600...  Training loss: 1.5435...  0.0560 sec/batch
# Epoch: 16/20...  Training Step: 60650...  Training loss: 1.5637...  0.0566 sec/batch
# Epoch: 16/20...  Training Step: 60700...  Training loss: 1.4721...  0.0540 sec/batch
# Epoch: 16/20...  Training Step: 60750...  Training loss: 1.4818...  0.0551 sec/batch
# Epoch: 16/20...  Training Step: 60800...  Training loss: 1.3530...  0.0572 sec/batch
# Epoch: 16/20...  Training Step: 60850...  Training loss: 1.4975...  0.0554 sec/batch
# Epoch: 16/20...  Training Step: 60900...  Training loss: 1.4101...  0.0548 sec/batch
# Epoch: 16/20...  Training Step: 60950...  Training loss: 1.7138...  0.0550 sec/batch
# Epoch: 16/20...  Training Step: 61000...  Training loss: 1.5063...  0.0549 sec/batch
# Epoch: 16/20...  Training Step: 61050...  Training loss: 1.6386...  0.0534 sec/batch
# Epoch: 16/20...  Training Step: 61100...  Training loss: 1.4296...  0.0560 sec/batch
# Epoch: 16/20...  Training Step: 61150...  Training loss: 1.5250...  0.0596 sec/batch
# Epoch: 16/20...  Training Step: 61200...  Training loss: 1.4555...  0.0537 sec/batch
# Epoch: 16/20...  Training Step: 61250...  Training loss: 1.5925...  0.0542 sec/batch
# Epoch: 16/20...  Training Step: 61300...  Training loss: 1.6242...  0.0543 sec/batch
# Epoch: 16/20...  Training Step: 61350...  Training loss: 1.5896...  0.0562 sec/batch
# Epoch: 16/20...  Training Step: 61400...  Training loss: 1.6803...  0.0543 sec/batch
# Epoch: 16/20...  Training Step: 61450...  Training loss: 1.3828...  0.0535 sec/batch
# Epoch: 16/20...  Training Step: 61500...  Training loss: 1.4914...  0.0534 sec/batch
# Epoch: 16/20...  Training Step: 61550...  Training loss: 1.5379...  0.0559 sec/batch
# Epoch: 16/20...  Training Step: 61600...  Training loss: 1.6875...  0.0568 sec/batch
# Epoch: 16/20...  Training Step: 61650...  Training loss: 1.5523...  0.0542 sec/batch
# Epoch: 16/20...  Training Step: 61700...  Training loss: 1.5887...  0.0605 sec/batch
# Epoch: 16/20...  Training Step: 61750...  Training loss: 1.5392...  0.0536 sec/batch
# Epoch: 16/20...  Training Step: 61800...  Training loss: 1.5281...  0.0570 sec/batch
# Epoch: 16/20...  Training Step: 61850...  Training loss: 1.4868...  0.0550 sec/batch
# Epoch: 16/20...  Training Step: 61900...  Training loss: 1.5939...  0.0600 sec/batch
# Epoch: 16/20...  Training Step: 61950...  Training loss: 1.6517...  0.0548 sec/batch
# Epoch: 16/20...  Training Step: 62000...  Training loss: 1.6875...  0.0540 sec/batch
# Epoch: 16/20...  Training Step: 62050...  Training loss: 1.5075...  0.0582 sec/batch
# Epoch: 16/20...  Training Step: 62100...  Training loss: 1.6086...  0.0566 sec/batch
# Epoch: 16/20...  Training Step: 62150...  Training loss: 1.5120...  0.0533 sec/batch
# Epoch: 16/20...  Training Step: 62200...  Training loss: 1.6551...  0.0543 sec/batch
# Epoch: 16/20...  Training Step: 62250...  Training loss: 1.6047...  0.0547 sec/batch
# Epoch: 16/20...  Training Step: 62300...  Training loss: 1.5062...  0.0538 sec/batch
# Epoch: 16/20...  Training Step: 62350...  Training loss: 1.4199...  0.0538 sec/batch
# Epoch: 16/20...  Training Step: 62400...  Training loss: 1.6052...  0.0562 sec/batch
# Epoch: 16/20...  Training Step: 62450...  Training loss: 1.4139...  0.0552 sec/batch
# Epoch: 16/20...  Training Step: 62500...  Training loss: 1.3695...  0.0540 sec/batch
# Epoch: 16/20...  Training Step: 62550...  Training loss: 1.5370...  0.0560 sec/batch
# Epoch: 16/20...  Training Step: 62600...  Training loss: 1.6165...  0.0543 sec/batch
# Epoch: 16/20...  Training Step: 62650...  Training loss: 1.5450...  0.0529 sec/batch
# Epoch: 16/20...  Training Step: 62700...  Training loss: 1.3938...  0.0555 sec/batch
# Epoch: 16/20...  Training Step: 62750...  Training loss: 1.6297...  0.0540 sec/batch
# Epoch: 16/20...  Training Step: 62800...  Training loss: 1.5662...  0.0575 sec/batch
# Epoch: 16/20...  Training Step: 62850...  Training loss: 1.5873...  0.0576 sec/batch
# Epoch: 16/20...  Training Step: 62900...  Training loss: 1.4334...  0.0567 sec/batch
# Epoch: 16/20...  Training Step: 62950...  Training loss: 1.5927...  0.0542 sec/batch
# Epoch: 16/20...  Training Step: 63000...  Training loss: 1.4752...  0.0549 sec/batch
# Epoch: 16/20...  Training Step: 63050...  Training loss: 1.4849...  0.0550 sec/batch
# Epoch: 16/20...  Training Step: 63100...  Training loss: 1.5766...  0.0544 sec/batch
# Epoch: 16/20...  Training Step: 63150...  Training loss: 1.5104...  0.0562 sec/batch
# Epoch: 16/20...  Training Step: 63200...  Training loss: 1.7585...  0.0568 sec/batch
# Epoch: 16/20...  Training Step: 63250...  Training loss: 1.4714...  0.0601 sec/batch
# Epoch: 16/20...  Training Step: 63300...  Training loss: 1.6414...  0.0569 sec/batch
# Epoch: 16/20...  Training Step: 63350...  Training loss: 1.5962...  0.0550 sec/batch
# Epoch: 16/20...  Training Step: 63400...  Training loss: 1.5646...  0.0553 sec/batch
# Epoch: 16/20...  Training Step: 63450...  Training loss: 1.6781...  0.0564 sec/batch
# Epoch: 16/20...  Training Step: 63500...  Training loss: 1.5373...  0.0588 sec/batch
# Epoch: 17/20...  Training Step: 63550...  Training loss: 1.5016...  0.0541 sec/batch
# Epoch: 17/20...  Training Step: 63600...  Training loss: 1.5372...  0.0550 sec/batch
# Epoch: 17/20...  Training Step: 63650...  Training loss: 1.5224...  0.0531 sec/batch
# Epoch: 17/20...  Training Step: 63700...  Training loss: 1.3967...  0.0541 sec/batch
# Epoch: 17/20...  Training Step: 63750...  Training loss: 1.5183...  0.0564 sec/batch
# Epoch: 17/20...  Training Step: 63800...  Training loss: 1.5702...  0.0567 sec/batch
# Epoch: 17/20...  Training Step: 63850...  Training loss: 1.6415...  0.0552 sec/batch
# Epoch: 17/20...  Training Step: 63900...  Training loss: 1.5996...  0.0577 sec/batch
# Epoch: 17/20...  Training Step: 63950...  Training loss: 1.4487...  0.0541 sec/batch
# Epoch: 17/20...  Training Step: 64000...  Training loss: 1.5744...  0.0571 sec/batch
# Epoch: 17/20...  Training Step: 64050...  Training loss: 1.5983...  0.0614 sec/batch
# Epoch: 17/20...  Training Step: 64100...  Training loss: 1.6796...  0.0567 sec/batch
# Epoch: 17/20...  Training Step: 64150...  Training loss: 1.6909...  0.0552 sec/batch
# Epoch: 17/20...  Training Step: 64200...  Training loss: 1.7103...  0.0543 sec/batch
# Epoch: 17/20...  Training Step: 64250...  Training loss: 1.4858...  0.0536 sec/batch
# Epoch: 17/20...  Training Step: 64300...  Training loss: 1.6490...  0.0546 sec/batch
# Epoch: 17/20...  Training Step: 64350...  Training loss: 1.4467...  0.0559 sec/batch
# Epoch: 17/20...  Training Step: 64400...  Training loss: 1.4921...  0.0564 sec/batch
# Epoch: 17/20...  Training Step: 64450...  Training loss: 1.5722...  0.0537 sec/batch
# Epoch: 17/20...  Training Step: 64500...  Training loss: 1.5479...  0.0530 sec/batch
# Epoch: 17/20...  Training Step: 64550...  Training loss: 1.5272...  0.0540 sec/batch

# %% [markdown]
# #### Saved checkpoints
#
# Read up on saving and loading checkpoints here: https://www.tensorflow.org/programmers_guide/variables

# %%
tf.train.get_checkpoint_state('checkpoints')

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    samples = [c for c in prime]
    model = CharRNN(len(vocab), lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %% [markdown]
# Here, pass in the path to a checkpoint and sample from the network.

# %%
tf.train.latest_checkpoint('checkpoints')

# %%
checkpoint = tf.train.latest_checkpoint('checkpoints')
samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
print(samp)

# %%
checkpoint = 'checkpoints/i200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)

# %%
checkpoint = 'checkpoints/i600_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)

# %%
checkpoint = 'checkpoints/i1200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
